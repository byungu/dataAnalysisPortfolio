# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('mode.chained_assignment', None)

# %%
data = pd.read_csv('data/행정구역별_소년범죄발생건수2018.csv', index_col=0, encoding = 'cp949', engine='python')

# %%
data
# Out:
#                                       2018               2018.1  \
# 행정구역별
# 행정구역별    소년 천명당 소년범죄발생건수<br>(A÷B×1000) (건)  소년범죄발생건수<br>(A) (건)
# 전국                                    12.9                66255
# 서울특별시                                 13.1                11193
# 부산광역시                                 19.4                 5738
# 대구광역시                                 13.1                 3277
# 인천광역시                                 16.1                 4706
# 광주광역시                                 14.2                 2438
# 대전광역시                                 14.0                 2246
# 울산광역시                                 12.4                 1509
# 경기도                                   12.4                17203
# 강원도                                   12.5                 1881
# 충청북도                                  13.6                 2171
# 충청남도                                  12.3                 3087
# ...

# %%
data_df = pd.DataFrame(data)

# %%
data_df = data_df.drop(columns=['2018'])

# %%
data_df = data_df.rename(columns={'2018.1':'소년범죄발생건수', '2018.2':'소년인구'})

# %%
data_df = data_df.drop(['행정구역별'], axis=0)

# %%
data_df
# Out:
#         소년범죄발생건수     소년인구
# 행정구역별
# 전국         66255  5131153
# 서울특별시      11193   855121
# 부산광역시       5738   296145
# 대구광역시       3277   249672
# 인천광역시       4706   292324
# 광주광역시       2438   171887
# 대전광역시       2246   160537
# 울산광역시       1509   121540
# 경기도        17203  1384896
# 강원도         1881   150060
# 충청북도        2171   159713
# 충청남도        3087   250246
# 전라북도        2399   190798
# 전라남도        1973   183499
# 경상북도        2620   245099
# 경상남도        2986   345897
# 제주특별자치도      828    73719

# %%
data_count = data_df['소년범죄발생건수']

# %%
data_count
# Out:
# 행정구역별
# 전국         66255
# 서울특별시      11193
# 부산광역시       5738
# 대구광역시       3277
# 인천광역시       4706
# 광주광역시       2438
# 대전광역시       2246
# 울산광역시       1509
# 경기도        17203
# 강원도         1881
# 충청북도        2171
# 충청남도        3087
# 전라북도        2399
# 전라남도        1973
# 경상북도        2620
# 경상남도        2986
# 제주특별자치도      828
# Name: 소년범죄발생건수, dtype: object

# %%
data_count = data_count.astype('float')
data_df = data_df.astype('float')

# %%
data_df['행정구역별소년범죄율'] = data_count.div(data_df['소년인구'], axis=0)*1000

# %%
data_df
# Out:
#          소년범죄발생건수       소년인구  행정구역별소년범죄율
# 행정구역별
# 전국        66255.0  5131153.0   12.912303
# 서울특별시     11193.0   855121.0   13.089376
# 부산광역시      5738.0   296145.0   19.375644
# 대구광역시      3277.0   249672.0   13.125220
# 인천광역시      4706.0   292324.0   16.098576
# 광주광역시      2438.0   171887.0   14.183737
# 대전광역시      2246.0   160537.0   13.990544
# 울산광역시      1509.0   121540.0   12.415666
# 경기도       17203.0  1384896.0   12.421871
# 강원도        1881.0   150060.0   12.534986
# 충청북도       2171.0   159713.0   13.593133
# 충청남도       3087.0   250246.0   12.335862
# 전라북도       2399.0   190798.0   12.573507
# 전라남도       1973.0   183499.0   10.752102
# 경상북도       2620.0   245099.0   10.689558
# 경상남도       2986.0   345897.0    8.632628
# 제주특별자치도     828.0    73719.0   11.231840

# %%
data_df['전체소년범죄비율'] = data_count.div(data_df['소년인구'][0], axis=0)*1000

# %%
data_df
# Out:
#          소년범죄발생건수       소년인구  행정구역별소년범죄율   전체소년범죄비율
# 행정구역별
# 전국        66255.0  5131153.0   12.912303  12.912303
# 서울특별시     11193.0   855121.0   13.089376   2.181381
# 부산광역시      5738.0   296145.0   19.375644   1.118267
# 대구광역시      3277.0   249672.0   13.125220   0.638648
# 인천광역시      4706.0   292324.0   16.098576   0.917143
# 광주광역시      2438.0   171887.0   14.183737   0.475137
# 대전광역시      2246.0   160537.0   13.990544   0.437718
# 울산광역시      1509.0   121540.0   12.415666   0.294086
# 경기도       17203.0  1384896.0   12.421871   3.352658
# 강원도        1881.0   150060.0   12.534986   0.366584
# 충청북도       2171.0   159713.0   13.593133   0.423102
# 충청남도       3087.0   250246.0   12.335862   0.601619
# 전라북도       2399.0   190798.0   12.573507   0.467536
# 전라남도       1973.0   183499.0   10.752102   0.384514
# 경상북도       2620.0   245099.0   10.689558   0.510606
# 경상남도       2986.0   345897.0    8.632628   0.581935
# 제주특별자치도     828.0    73719.0   11.231840   0.161367

# %%
data_count2 = data_df['소년범죄발생건수']

# %%
data_count2 = data_count2.astype('float')

# %%
data_df['건수당범죄비율'] = data_count.div(data_df['소년범죄발생건수'][0], axis=0)*100

# %%
data_df
# Out:
#          소년범죄발생건수       소년인구  행정구역별소년범죄율   전체소년범죄비율     건수당범죄비율
# 행정구역별
# 전국        66255.0  5131153.0   12.912303  12.912303  100.000000
# 서울특별시     11193.0   855121.0   13.089376   2.181381   16.893819
# 부산광역시      5738.0   296145.0   19.375644   1.118267    8.660478
# 대구광역시      3277.0   249672.0   13.125220   0.638648    4.946042
# 인천광역시      4706.0   292324.0   16.098576   0.917143    7.102860
# 광주광역시      2438.0   171887.0   14.183737   0.475137    3.679722
# 대전광역시      2246.0   160537.0   13.990544   0.437718    3.389933
# 울산광역시      1509.0   121540.0   12.415666   0.294086    2.277564
# 경기도       17203.0  1384896.0   12.421871   3.352658   25.964833
# 강원도        1881.0   150060.0   12.534986   0.366584    2.839031
# 충청북도       2171.0   159713.0   13.593133   0.423102    3.276734
# 충청남도       3087.0   250246.0   12.335862   0.601619    4.659271
# 전라북도       2399.0   190798.0   12.573507   0.467536    3.620859
# 전라남도       1973.0   183499.0   10.752102   0.384514    2.977888
# ...

# %%
data_df_ratio = data_df.drop(['전국'], axis=0)

# %%
data_df_ratio
# Out:
#          소년범죄발생건수       소년인구  행정구역별소년범죄율  전체소년범죄비율    건수당범죄비율
# 행정구역별
# 서울특별시     11193.0   855121.0   13.089376  2.181381  16.893819
# 부산광역시      5738.0   296145.0   19.375644  1.118267   8.660478
# 대구광역시      3277.0   249672.0   13.125220  0.638648   4.946042
# 인천광역시      4706.0   292324.0   16.098576  0.917143   7.102860
# 광주광역시      2438.0   171887.0   14.183737  0.475137   3.679722
# 대전광역시      2246.0   160537.0   13.990544  0.437718   3.389933
# 울산광역시      1509.0   121540.0   12.415666  0.294086   2.277564
# 경기도       17203.0  1384896.0   12.421871  3.352658  25.964833
# 강원도        1881.0   150060.0   12.534986  0.366584   2.839031
# 충청북도       2171.0   159713.0   13.593133  0.423102   3.276734
# 충청남도       3087.0   250246.0   12.335862  0.601619   4.659271
# 전라북도       2399.0   190798.0   12.573507  0.467536   3.620859
# 전라남도       1973.0   183499.0   10.752102  0.384514   2.977888
# 경상북도       2620.0   245099.0   10.689558  0.510606   3.954419
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams, style
style.use('ggplot')

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family = font_name)

# %%
city_crim = data_df_ratio['행정구역별소년범죄율']

# %%
city_crim
# Out:
# 행정구역별
# 서울특별시      13.089376
# 부산광역시      19.375644
# 대구광역시      13.125220
# 인천광역시      16.098576
# 광주광역시      14.183737
# 대전광역시      13.990544
# 울산광역시      12.415666
# 경기도        12.421871
# 강원도        12.534986
# 충청북도       13.593133
# 충청남도       12.335862
# 전라북도       12.573507
# 전라남도       10.752102
# 경상북도       10.689558
# 경상남도        8.632628
# 제주특별자치도    11.231840
# Name: 행정구역별소년범죄율, dtype: float64

# %%
city_crim2 = data_df_ratio['건수당범죄비율']

# %%
label = ['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', 
         '대전광역시', '울산광역시', '경기도', '강원도', '충청북도', '충청남도', 
         '전라북도', '전라남도', '경상북도', '경상남도', '제주특별자치도']

# %%
plt.rcParams['figure.figsize'] = (20, 10)
x = np.arange(len(label))

plt.bar(x-0.2, city_crim, label = '행정구역별범죄율', width = 0.4, color='red')
plt.bar(x+0.20, city_crim2, label = '건수당범죄율',  width = 0.4, color='blue')
plt.xticks(x, label, fontsize=15, rotation=45)
plt.yticks(fontsize=15)
plt.legend(fontsize=15)
plt.xlabel('행정구역', fontsize=15)
plt.ylabel('행정구역별 범죄율/건수당범죄율', fontsize=15)
plt.ylim(0, 30)
plt.title('2018 행정구역별 소년범죄율', fontsize=15)
plt.savefig('data/2018_행정구역별_소년범죄율.png')
plt.show()
plt.close()

# %%
# 블록맵 맵핑
import os
path = os.getcwd()

# %%
data_draw_korea = pd.read_csv('data/data_draw_korea.csv', 
                              index_col = 0, encoding = 'utf-8', engine = 'python')
data_draw_korea.head()
# Out:
#       인구수 shortName   x  y       면적 광역시도 행정구역
# 0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1   25589    고성(강원)   9  0   664.19  강원도  고성군
# 2   86747        동해  11  5   180.01  강원도  동해시
# 3   63986        삼척  11  8  1185.80  강원도  삼척시
# 4   76733        속초   9  1   105.25  강원도  속초시

# %%
df1 = data_draw_korea.drop(columns=['인구수', 'shortName', '면적'])
# 필요없는 데이터 삭제

# %%
df1['시도군구'] = data_draw_korea.apply(lambda v: v['광역시도']+' '+v['행정구역'], axis=1)
# '시도군구' 칼럼추가

# %%
df1.iloc[149]
# Out:
# x                 4
# y                11
# 광역시도        세종특별자치시
# 행정구역            세종시
# 시도군구    세종특별자치시 세종시
# Name: 149, dtype: object

# %%
df1.iloc[149] = [4, 11, '충청남도', '세종시', '충청남도 세종시']

# %%
df2 = df1['시도군구'] # 시도군구의 데이터 개수를 위해서 리스트 생성

# %%
city = city_crim.index # 인덱스 값이 행정구역 이름이니 이것으로 데이터값을 받을 수 있게 변수생성

# %%
crim = data_df_ratio['행정구역별소년범죄율'].tolist()
# list형으로 바꿔야만 for문으로 반복할 수 있으므로 변경

# %%
list = []
for i in range(len(df2)):
    sido = df1['광역시도'][i]
    for x in range(len(city)):
        sido2 = city[x]
        crim2 = crim[x]
        
        if sido == sido2:
            list.append(crim2)

# for문으로 df1의 광역시도가 범죄율의 리스트형의 인덱스 값이 같으면 데이터를 list에 담는다.

# %%
list
# Out:
# [12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.534986005597762,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
#  12.421871389620591,
# ...

# %%
df1 = df1.set_index('시도군구')

# %%
df1['시도별소년범죄율'] = list

# %%
df1.head()
# Out:
#           x  y 광역시도 행정구역   시도별소년범죄율
# 시도군구
# 강원도 강릉시  11  4  강원도  강릉시  12.534986
# 강원도 고성군   9  0  강원도  고성군  12.534986
# 강원도 동해시  11  5  강원도  동해시  12.534986
# 강원도 삼척시  11  8  강원도  삼척시  12.534986
# 강원도 속초시   9  1  강원도  속초시  12.534986

# %%
list2 = []
for i in range(len(df2)):
    sido = df1['행정구역'][i]
    if sido != None:
        list2.append(' ')

# %%
df1['name'] = list2

# %%
df1.head()
# Out:
#           x  y 광역시도 행정구역   시도별소년범죄율 name
# 시도군구
# 강원도 강릉시  11  4  강원도  강릉시  12.534986
# 강원도 고성군   9  0  강원도  고성군  12.534986
# 강원도 동해시  11  5  강원도  동해시  12.534986
# 강원도 삼척시  11  8  강원도  삼척시  12.534986
# 강원도 속초시   9  1  강원도  속초시  12.534986

# %%
BORDER_LINES = [
    [(3, 2), (5, 2), (5, 3), (9, 3), (9, 1)], # 인천
    [(2, 5), (3, 5), (3, 4), (8, 4), (8, 7), (7, 7), (7, 9), (4, 9), (4, 7), (1, 7)], # 서울
    [(1, 6), (1, 9), (3, 9), (3, 10), (8, 10), (8, 9),
     (9, 9), (9, 8), (10, 8), (10, 5), (9, 5), (9, 3)], # 경기도
    [(9, 12), (9, 10), (8, 10)], # 강원도
    [(10, 5), (11, 5), (11, 4), (12, 4), (12, 5), (13, 5),
     (13, 4), (14, 4), (14, 2)], # 충청남도
    [(11, 5), (12, 5), (12, 6), (15, 6), (15, 7), (13, 7),
     (13, 8), (11, 8), (11, 9), (10, 9), (10, 8)], # 충청북도
    [(14, 4), (15, 4), (15, 6)], # 대전시
    [(14, 7), (14, 9), (13, 9), (13, 11), (13, 13)], # 경상북도
    [(14, 8), (16, 8), (16, 10), (15, 10),
     (15, 11), (14, 11), (14, 12), (13, 12)], # 대구시
    [(15, 11), (16, 11), (16, 13)], # 울산시
    [(17, 1), (17, 3), (18, 3), (18, 6), (15, 6)], # 전라북도
    [(19, 2), (19, 4), (21, 4), (21, 3), (22, 3), (22, 2), (19, 2)], # 광주시
    [(18, 5), (20, 5), (20, 6)], # 전라남도
    [(16, 9), (18, 9), (18, 8), (19, 8), (19, 9), (20, 9), (20, 10)], # 부산시
]
def draw_bolockMap(blockedMap, targetData, title, color):
    whitelabelmin = (max(blockedMap[targetData]) - min(blockedMap[targetData])) \
                    * 0.25+min(blockedMap[targetData])
    datalabel = targetData

    vmin = min(blockedMap[targetData])
    vmax = max(blockedMap[targetData])

    mapdata = blockedMap.pivot(index='y', columns='x', values=targetData)
    masked_mapdata = np.ma.masked_where(np.isnan(mapdata), mapdata)

    plt.figure(figsize=(8, 13))
    plt.title(title)
    plt.pcolor(masked_mapdata, vmin=vmin, vmax=vmax, cmap=color, edgecolor='#aaaaaa', linewidth=0.5)

    for idx, row in blockedMap.iterrows():
        annocolor = 'white' if row[targetData] > whitelabelmin else 'black'

#         if row['광역시도'].endswith('시') and not row['광역시도'].startswith('세종'):
#             dispname = '{}\n{}'.format(row['광역시도'][:2], row['행정구역'][:-1])
#             if len(row['행정구역']) <=2:
#                 dispname += row['행정구역'][-1]
#         else:
#             dispname = row['행정구역'][:-1]
        dispname = row['name']

        if len(dispname.splitlines()[-1]) >= 3:
            fontsize, linespacing = 9.5, 1.5
        else:
            fontsize, linespacing = 11, 1.2

        plt.annotate(dispname, (row['x']+0.5, row['y']+0.5), weight='bold',
                     fontsize=fontsize, ha='center', va='center', color=annocolor,
                     linespacing=linespacing)

    for path in BORDER_LINES:
        ys, xs = zip(*path)
        plt.plot(xs, ys, c='black', lw=4)

    plt.gca().invert_yaxis()
    plt.axis('off')

    cb = plt.colorbar(shrink= .1, aspect=10)
    cb.set_label(datalabel)

    plt.tight_layout()
    plt.savefig('.\\data\\' + 'blockMap_' + targetData + '.png')

    plt.show()

# %%
print(draw_bolockMap(df1, '시도별소년범죄율',
                            '2018 행정구역별 소년범죄율', 'Reds' ))
# Out:
# C:\Users\ymca1\AppData\Local\Temp\ipykernel_10164\2813546220.py:34: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.pcolor(masked_mapdata, vmin=vmin, vmax=vmax, cmap=color, edgecolor='#aaaaaa', linewidth=0.5)
# C:\Users\ymca1\AppData\Local\Temp\ipykernel_10164\2813546220.py:63: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   cb = plt.colorbar(shrink= .1, aspect=10)
# None
